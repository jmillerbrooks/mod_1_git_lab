# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_pickle('budget_by_genre.pkl')

df.head()
exploded_df = df.explode('genre_list')
exploded_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 0   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 0   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1   3   Jun 7, 2019                                 Dark Phoenix
# 1   3   Jun 7, 2019                                 Dark Phoenix
#
#    production_budget  domestic_gross  worldwide_gross  year  domestic_profit  \
# 0        410600000.0     241063875.0     1.045664e+09  2011     -169536125.0
# 0        410600000.0     241063875.0     1.045664e+09  2011     -169536125.0
# 0        410600000.0     241063875.0     1.045664e+09  2011     -169536125.0
# 1        350000000.0      42762350.0     1.497624e+08  2019     -307237650.0
# 1        350000000.0      42762350.0     1.497624e+08  2019     -307237650.0
#
#    worldwide_profit  domestic_roi  worldwide_roi     tconst  \
# 0       635063875.0      0.587101       2.546673  tt1298650
# 0       635063875.0      0.587101       2.546673  tt1298650
# 0       635063875.0      0.587101       2.546673  tt1298650
# 1      -200237650.0      0.122178       0.427892  tt6565702
# 1      -200237650.0      0.122178       0.427892  tt6565702
#
#                                  primary_title  \
# 0  Pirates of the Caribbean: On Stranger Tides
# 0  Pirates of the Caribbean: On Stranger Tides
# 0  Pirates of the Caribbean: On Stranger Tides
# 1                                 Dark Phoenix
# 1                                 Dark Phoenix
#
#                                 original_title  start_year  runtime_minutes  \
# 0  Pirates of the Caribbean: On Stranger Tides        2011            136.0
# 0  Pirates of the Caribbean: On Stranger Tides        2011            136.0
# 0  Pirates of the Caribbean: On Stranger Tides        2011            136.0
# 1                                 Dark Phoenix        2019            113.0
# 1                                 Dark Phoenix        2019            113.0
#
#                      genres genre_list
# 0  Action,Adventure,Fantasy     Action
# 0  Action,Adventure,Fantasy  Adventure
# 0  Action,Adventure,Fantasy    Fantasy
# 1   Action,Adventure,Sci-Fi     Action
# 1   Action,Adventure,Sci-Fi  Adventure

# %%
df.genres.value_counts().head(20)
# Out:
# Drama                         68
# Adventure,Animation,Comedy    67
# Comedy                        56
# Comedy,Drama,Romance          52
# Action,Adventure,Sci-Fi       52
# Comedy,Drama                  49
# Comedy,Romance                41
# Action,Crime,Drama            39
# Documentary                   36
# Drama,Romance                 34
# Action,Comedy,Crime           32
# Action,Adventure,Fantasy      31
# Horror,Mystery,Thriller       31
# Action,Adventure,Drama        28
# Drama,Thriller                25
# Horror,Thriller               24
# Action,Crime,Thriller         23
# Crime,Drama,Thriller          22
# Action,Adventure,Comedy       22
# Biography,Drama,History       20
# Name: genres, dtype: int64

# %%
genre_cats = exploded_df.genre_list.value_counts().head(13)

# %%
# plt.scatter(exploded_df.year, exploded_df.worldwide_profit, s=exploded_df.production_budget, c=exploded_df.genre_list)
# plt.show()
g = sns.scatterplot(y="year", x="worldwide_profit",
                    data=exploded_df[exploded_df.genre_list.isin(genre_cats.index)],
                    hue='genre_list', size="production_budget",
                    size_norm=1000000)
g.legend(loc='lower right')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-586e593cbbfa> in <module>
#       4                     data=exploded_df[exploded_df.genre_list.isin(genre_cats.index)],
#       5                     hue='genre_list', size="production_budget",
# ----> 6                     size_norm=1000000)
#       7 g.legend(loc='lower right')
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1400         x_bins=x_bins, y_bins=y_bins,
#    1401         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1402         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1403     )
#    1404
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     897
#     898         self.parse_hue(plot_data["hue"], palette, hue_order, hue_norm)
# --> 899         self.parse_size(plot_data["size"], sizes, size_order, size_norm)
#     900         self.parse_style(plot_data["style"], markers, None, style_order)
#     901         self.units = units
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in parse_size(self, data, sizes, order, norm)
#     471                     err = ("``size_norm`` must be None, tuple, "
#     472                            "or Normalize object.")
# --> 473                     raise ValueError(err)
#     474
#     475                 norm.clip = True
#
# ValueError: ``size_norm`` must be None, tuple, or Normalize object.
