# %% [markdown]
# <h1>PROJECT 1

# %% [markdown]
# <h3>Explore what type of films are currently doing the best at the box office.

# %% [markdown]
# Pose at least 3 meaningful questions to be answered through EDA:
# 1) Are there patterns within genres that appear to be profitable? How about runtime?
# 2)Are there studios or other stakeholders who have a profitable pattern? Better are there smaller studios that Microsoft could purchase outright?
# 3) Are there different tiers of investment that Microsoft could approach this from, and does the approach differ for these tiers (i.e. are there different genres/studios/stakeholders for different levels of investment) — followup: is there a natural scalable roadmap or would microsoft need to pick a tier initially and start from scratch if leveling up?
# 2) Project Pitch Monday
# Plan on using budget dataset (tn.movie_budgets)
# Plan also on using rt.movie_info set potentially imdb title principals/crew
# See above questions
# We could visualize several levels of investment or several genres, using histograms, scatter plots colored by genre, etc.

# %%
import pandas as pd
import glob, os

file_path = "/users/bobbywilliams/dc-ds-060120/mod-1/Mod-1-project/zippeddata/"
os.chdir(file_path)
datasets = []
# Loop through the available files and create a list of their names for dynamic creation of dataframes
for file in glob.glob("*"):
    
    file_name = list(file.split("."))
    
    file_parts = len(file_name)
    
    dataset = file_name[:file_parts-2]
    
#    for set in dataset:
#        dataframe_name = 
    
    datasets.append(dataset)
    
    print(file)
    
    #print(file_parts)

datasets
# Out:
# imdb.title.crew.csv.gz
# tmdb.movies.csv.gz
# imdb.title.akas.csv.gz
# imdb.title.ratings.csv.gz
# imdb.name.basics.csv.gz
# rt.reviews.tsv.gz
# imdb.title.basics.csv.gz
# rt.movie_info.tsv.gz
# tn.movie_budgets.csv.gz
# bom.movie_gross.csv.gz
# imdb.title.principals.csv.gz
# [['imdb', 'title', 'crew'],
#  ['tmdb', 'movies'],
#  ['imdb', 'title', 'akas'],
#  ['imdb', 'title', 'ratings'],
#  ['imdb', 'name', 'basics'],
#  ['rt', 'reviews'],
#  ['imdb', 'title', 'basics'],
#  ['rt', 'movie_info'],
#  ['tn', 'movie_budgets'],
#  ['bom', 'movie_gross'],
#  ['imdb', 'title', 'principals']]

# %%
df_imdb_title_crew = pd.read_csv(file_path + 'imdb.title.crew.csv.gz')
df_tmdb_movies = pd.read_csv(file_path + 'tmdb.movies.csv.gz')
df_imdb_title_akas = pd.read_csv(file_path + 'imdb.title.akas.csv.gz')
df_imdb_title_ratings = pd.read_csv(file_path + 'imdb.title.ratings.csv.gz')
df_imdb_name_basics = pd.read_csv(file_path + 'imdb.name.basics.csv.gz')
#df_rt_reviews = pd.read_csv(file_path + 'rt.reviews.tsv.gz')
df_imdb_title_basics = pd.read_csv(file_path + 'imdb.title.basics.csv.gz')
#df_rt_movie_info = pd.read_csv(file_path + 'rt.movie_info.tsv.gz')
df_tn_movie_budgets = pd.read_csv(file_path + 'tn.movie_budgets.csv.gz')
df_bom_movie_gross = pd.read_csv(file_path + 'bom.movie_gross.csv.gz')
df_imdb_title_principals = pd.read_csv(file_path + 'imdb.title.principals.csv.gz')

# %%
#df_rt_reviews = pd.read_table(file_path + 'rt.reviews.tsv.gz')

# %%
# encoding = Latin
import chardet    
rawdata = open(file_path + 'rt.reviews.tsv.gz', "rb").read()
result = chardet.detect(rawdata)
charenc = result['encoding']
print(charenc)
# Out:
# None

# %%
with open(file_path + 'rt.reviews.tsv.gz', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(2000))
# check what the character encoding might be
print(result)
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
# df_imdb_title_crew.columns()
    # tconst
    # directors (many)
    # writers (many)

# df_tmdb_movies
    # Unnamed: 0
    # genre_ids
    # id
    # original_language
    # original_title
    # popularity
    # release_date
    # title
    # vote_average
    # vote_count

# df_imdb_title_akas
    # title_id --- same as tconst
    # ordering
    # title
    # region
    # language
    # types
    # attributes
    # is_original_title

# df_imdb_title_ratings
    # tconst
    # averagerating
    # numvotes

#df_imdb_name_basics
    # nconst
    # primary_name
    # birth_year
    # death_year
    # primary_profession (many)
    # known_for_titles (many)

#########
# df_rt_reviews
    # didn't load

#df_imdb_title_basics
    # tconst
    # primary_title
    # original_title
    # start_year
    # runtime_minutes
    # genres

#########
# df_rt_movie_info
    # didn't load

# df_tn_movie_budgets
    # id
    # release_date
    # movie
    # production_budget
    # domestic_gross
    # worldwide_gross

# df_bom_movie_gross
    # title
    # studio
    # domestic_gross
    # foreign_gross
    # year

# df_imdb_title_principals
    # tconst
    # ordering
    # nconst
    # category
    # job
    # characters

# %%
df_imdb_title_crew.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
df_imdb_title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
# tconst in known_for_titles
df_imdb_name_basics.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
df_imdb_title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df_imdb_title_principals.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
# df_imdb_title_basics ahs 146144 entries
# df_imdb_title_ratings has 73856 entries
# Merge the dfs into a new df keeping the title_basics and addings the title ratings where possible

# %%
df_imdb_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
df_imdb_title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
result = pd.concat([df_imdb_title_basics, df_imdb_title_ratings], axis=1, sort=False)

# %%
result.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres      tconst  \
# 0        2013            175.0    Action,Crime,Drama  tt10356526
# 1        2019            114.0       Biography,Drama  tt10384606
# 2        2018            122.0                 Drama   tt1042974
# 3        2018              NaN          Comedy,Drama   tt1043726
# 4        2017             80.0  Comedy,Drama,Fantasy   tt1060240
#
#    averagerating  numvotes
# 0            8.3      31.0
# 1            8.9     559.0
# 2            6.4      20.0
# ...

# %%
first_merge = df_imdb_title_basics.merge(df_imdb_title_ratings, left_on='tconst', right_on='tconst', how = 'left')
first_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146144 entries, 0 to 146143
# Data columns (total 8 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# averagerating      73856 non-null float64
# numvotes           73856 non-null float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 10.0+ MB

# %%
df_bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df_bom_movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
sec_merge = df_imdb_title_basics.merge(df_bom_movie_gross, left_on='primary_title', right_on='title', how = 'left')
sec_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146146 entries, 0 to 146145
# Data columns (total 11 columns):
# tconst             146146 non-null object
# primary_title      146146 non-null object
# original_title     146125 non-null object
# start_year         146146 non-null int64
# runtime_minutes    114407 non-null float64
# genres             140738 non-null object
# title              3366 non-null object
# studio             3363 non-null object
# domestic_gross     3342 non-null float64
# foreign_gross      2043 non-null object
# year               3366 non-null float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 13.4+ MB

# %%
sec_merge.tail()
# Out:
#            tconst                                primary_title  \
# 146141  tt9916538                          Kuambil Lagi Hatiku
# 146142  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146143  tt9916706                              Dankyavar Danka
# 146144  tt9916730                                       6 Gunn
# 146145  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 146141                          Kuambil Lagi Hatiku        2019
# 146142  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146143                              Dankyavar Danka        2013
# 146144                                       6 Gunn        2017
# 146145               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes       genres title studio  domestic_gross  \
# 146141            123.0        Drama   NaN    NaN             NaN
# ...

# %%
df_imdb_title_basics.tail()
# Out:
#            tconst                                primary_title  \
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes       genres
# 146139            123.0        Drama
# 146140              NaN  Documentary
# 146141              NaN       Comedy
# 146142            116.0          NaN
# ...

# %%
df_imdb_title_basics['genres'].unique_items
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-f31c519cc37e> in <module>
# ----> 1 df_imdb_title_basics['genres'].unique_items
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'unique_items'
